# %%
# Simple linear regression
# Multiple Linear Regresion 
# Polynomial Regresion

# %%
''' 
Linear Progression(SLR)
Una variable independiente para hacer una prediccion entre dos variables
    X1
    
    *The predictor (independent) variable -x
    *The target (dependent) variable -y   
    

1 Import linear_model from scikit-learn
    from sklear.linear_model import LinearRegression
    
2 Create a Linear Regression Objet using the constructor:
    im-LinearRegression()
    
    
We define the predictor variable and target variable
x = df[['highway-mpg']]
y = df['price']

Then use lm.fit(X,Y) to fit the model, i.e fine the parameters b0 and b1

lm.fit(X,Y)

We can obtain a prediction

Yhat = lm.predict(X)

We can view the intercept(b0)

We can also view the slope (b1)

The Relationship between price and Highway MPG is given by
Price = 38423.31 - 821.73*highway-mpg
    
'''

# %%
'''
Multiple Linear Progression(MLR)
Multiple variables para hacer una prediccion
    X1.....Xd
    
One continuos target(Y)variable
Two or more predictor (X)variables
    
    Y = b0 + b1x1 + b2x2 + b3x3 + b4x4
    
    
    b0: intercept(X=0)
    b1: the coefficinet or parameter of x1
    b2: the coefficient of parameter x2 and so on...
    
    Y = 1 + 2x1 + 3x2
    
We can extrat the for 4 predictor variables and store them in the variable Z

    Z = df[['horsepower', 'curb-weight', 'engine-size','highway-mpg']]
    
Then train the model as before:

    lm.fit(Z, df['price'])

We can also obtain a prediction
    yhat = lm.predict(X)
    
1 Find the intercept(b0)
2 Find the coefficients(b1,b2,b3,b4)

    
 
'''
